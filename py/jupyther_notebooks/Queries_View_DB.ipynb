# %%
# %load_ext sql

# %%
# %config SqlMagic.displaylimit=1000

# %%
# %%sql duckdb:///C:/Users/mhu/Documents/github/magpie_chatbot/data/view_magpie_queries.db
# SELECT DISTINCT reichweite_beschr_list
# FROM view_daten_reichweite_menge
# WHERE variable_beschr = 'Technisches FuE-Personal'
# Out:
# +-----------------------------------------------------------------------------------------------------------+
# |                                           reichweite_beschr_list                                          |
# +-----------------------------------------------------------------------------------------------------------+
# |           Wirtschaftssektor | Deutschland | H.v. DV-Geräten, elektronischen u. opt. Erzeugnissen          |
# |                          Wirtschaftssektor | Deutschland | Sonstiger Fahrzeugbau                          |
# |  Wirtschaftssektor | weiblich | Deutschland | H.v. Nahrungs- u. Futtermitteln, Getränken u.Tabakerzeugn.  |
# |              Wirtschaftssektor | weiblich | Deutschland | H.v. pharmazeutischen Erzeugnissen              |
# |                      Wirtschaftssektor | Deutschland | H.v. elektrischen Ausrüstungen                     |
# ...

# %%
# %%sql
# SELECT wert, wert_einheit
# FROM view_daten_reichweite_menge
# WHERE variable_beschr = 'Technisches FuE-Personal'
# AND reichweite_beschr_list = 'Wirtschaftssektor | Deutschland'
# AND date_part('year', zeit_start) = 2021
# AND wert_einheit = 'VZÄ'
# LIMIT 5;
# Out:
# Running query in 'duckdb:///C:/Users/mhu/Documents/github/magpie_chatbot/data/view_magpie_queries.db'
# +--------+--------------+
# |  wert  | wert_einheit |
# +--------+--------------+
# | 146198 |     VZÄ      |
# +--------+--------------+
